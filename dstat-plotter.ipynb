# %% [markdown]
# <H3>dstat csv output can be plotted in a notebook using pandas and matplotlib

# %% [markdown]
# <code>Install the python libs with pip

# %%
# !pip install pandas matplotlib six --upgrade
# Out:
# Requirement already up-to-date: pandas in /usr/lib64/python2.7/site-packages
# Requirement already up-to-date: matplotlib in /usr/lib64/python2.7/site-packages
# Requirement already up-to-date: six in /usr/lib/python2.7/site-packages
# Requirement already up-to-date: python-dateutil in /usr/lib/python2.7/site-packages (from pandas)
# Requirement already up-to-date: numpy>=1.9.0 in /usr/lib64/python2.7/site-packages (from pandas)
# Requirement already up-to-date: pytz>=2011k in /usr/lib/python2.7/site-packages (from pandas)
# Requirement already up-to-date: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/lib/python2.7/site-packages (from matplotlib)
# Requirement already up-to-date: backports.functools-lru-cache in /usr/lib/python2.7/site-packages (from matplotlib)
# Requirement already up-to-date: subprocess32 in /usr/lib64/python2.7/site-packages (from matplotlib)
# Requirement already up-to-date: cycler>=0.10 in /usr/lib/python2.7/site-packages (from matplotlib)

# %%
import urllib
import json
import pandas as pd
# %matplotlib inline
import matplotlib

# %% [markdown]
# <H3>Use Pandas and Matplorlib to graph the csv output from dstat

# %%
FILENAME="gigiot.csv"
df=pd.read_csv(FILENAME, index_col=False, header=2, skiprows=3 )

# %%
plotfoo=df.plot(subplots=True, figsize=(30, 150))
